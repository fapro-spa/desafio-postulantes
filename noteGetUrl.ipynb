# %%
from tabulate import tabulate
from main import getURL

salida = getURL()
#print(salida.to_markdown()) 
print(tabulate(salida, headers='keys', tablefmt='psql'))
# Out:
# +-----+-------+------------------------------------------------------------------------------------------------------+---------------------------+----------------------------------------------+------------------+-----------------------------------------------------+-----------------------------------------------+
# |     |   No. | RAZÓN SOCIAL                                                                                         | PAÍS                      | DATOS INSCRIPCIÓN (DR / RES. No / FECHA)     | VIGENCIA HASTA   | DATOS ÚLTIMA ACTUALIZACIÓN (DR / RES. No / FECHA)   | ESTADO (ACTUALIZADO / EXCLUIDO / PENDIENTE)   |
# |-----+-------+------------------------------------------------------------------------------------------------------+---------------------------+----------------------------------------------+------------------+-----------------------------------------------------+-----------------------------------------------|
# ...
